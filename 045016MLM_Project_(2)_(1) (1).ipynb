# %% [markdown]
# Deepankar Vashishta 045016
#
# Segmentation of Consumer Data using Supervised Machine Learning
#
# Objective: The goal is to segment consumers based on their similar characteristics, behavior, and get on a single decison.
#
# Approach: Compare the performance of different classification models (Decision
# Tree, Logistic Regression, Support Vector Machine, K Nearest Neighbour) to determine the most
# suitable model for the dataset.
#
# Data: The dataset contains details of customers, including their marital status, income, number of items purchased, and types of items purchased.
#
# Preprocessing: Data Shape: The dataset has dimensions (66708, 12). Features for Clustering: We'll consider features such as Ratings, Reviews, and Original Price.
# Determination of Segment or Cluster Characteristics
#
# Interpretation: Once we have the optimal number of clusters, we'll analyze the characteristics of each segment. This involves understanding the common traits, preferences, and behaviors of customers within each cluster. We will analyze non-categorical data like reviews, prices, and ratings.
#
# Insights: We'll provide insights into the distinct features of each segment, which can guide Ratings, Reviews, and Prices.
#
# Index Variable(s): These are the identifiers for each record in your dataset. They are typically used for referencing specific rows.
#
# Categorical Variables or Features (CV): These variables represent categories or groups. Let’s further explore the subtypes:
#
# Variables with Nominal Categories (CNV): These are categorical features where the order of categories doesn’t matter. Examples from your dataset include: BrandName, Category, Individual_category.
#
# Variables with Ordinal Categories (COV): These are categorical features where the order of categories matters. Examples from your dataset include: SizeOption.
#
# Non-Categorical Variables or Features: These variables are numeric or continuous. They do not fall into the categorical category. Examples from your dataset include: Product_id, OriginalPrice, Ratings, Reviews, DiscountPrice, DiscountOffer.
#
# Descriptive Statistics: Categorical Variables or Features
# **Description of Variables:**
#
# - **Index Variable(s):** Cluster_number
# - **Outcome Variable or Feature (OV):** DiscountOffer
# - **Input Variables or Features having Categories (ICV):**
#   - **Input Variables or Features having Nominal Categories (ICNV):**
#     - BrandName
#     - Category
#     - Individual_category
#     - category_by_Gender
#   - **Input Variables or Features having Ordinal Categories (ICOV):**
#     - SizeOption
# - **Input Non-Categorical Variables or Features (INCV):**
#   - OriginalPrice (in Rs)
#   - Ratings
#   - Reviews
#   - DiscountPrice (in Rs)
#   Missing Data Statistics: Records There are no missing values in any of the records (rows). All records have complete data.
#
# Missing Data Statistics: Categorical Variables or Features There are no missing values in any of the categorical variables (columns)
#
# Boxplot Visualization:
# The code creates a boxplot to visualize the distribution of these features.
# Each feature has its own boxplot, allowing us to understand their central tendency, spread, and presence of outliers.
#
# Boxplot Interpretation:
# ‘OriginalPrice (in Rs)’:
# The boxplot for this feature shows a wide range of values.
# There are several outliers above the upper whisker, indicating that some products have significantly higher prices than the majority.
#
# Ratings’:
# The ratings feature exhibits one outlier.
# Most ratings seem to be clustered around a specific value.
#
# ‘Reviews’:
# The reviews feature also has an outlier.
# Data is concentrated around a median value.
#
# ‘DiscountPrice (in Rs)’ and ‘DiscountOffer’:
# Both features show no outliers.
# Their data spread is relatively small compared to ‘OriginalPrice’.
#
#
# Selection of Input and output Variables
#
# The objective is to select input variables for further analysis from the preprocessed DataFrame the selected variables are BrandName_y', 'Category_y', 'Individual_category_y', 'Description_y', 'SizeOption_y', 'Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'DiscountPrice (in Rs)','Reviews','DiscountOffer' and the output variable is Gender_category.
#
# Decision Tree
# Importance & Feature
# Category_y: This feature has the highest importance, with a score of 1.0. It suggests that the category of the product (perhaps in a dataset) is the most influential in whatever analysis or prediction task was performed. For example, if you're predicting sales, the category of a product might be the strongest predictor of its sales volume.
#
# BrandName_y: This feature has an importance score of 0.0, indicating that it does not contribute to the analysis. It suggests that the brand name associated with the product does not significantly affect the outcome being studied.
#
# Individual_category_y, Description_y, SizeOption_y, Product_id, OriginalPrice (in Rs), Ratings, DiscountPrice (in Rs), Reviews, DiscountOffer: Similar to BrandName_y, all these features have importance scores of 0.0. This implies that none of these features contribute significantly to the analysis or prediction task at hand.
#
# Analysis of the decision tree:
#
# Root Node:
# The root node represents the initial decision point. In this case, it evaluates the feature “Category y.”
# If “Category y” is less than or equal to 0.5, the tree proceeds to the left branch; otherwise, it takes the right branch.
# First Level:
# If “Category y” is less than or equal to 0.5:
# The left branch leads to a leaf node with a class label of 1.0 (indicating a positive outcome).
# The gini impurity at this node is 0, meaning all samples belong to the same class.
# The total number of samples here is 67,708.
# If “Category y” is greater than 0.5 but less than or equal to 6.5:
# The right branch further evaluates “Category y.”
# If “Category y” is less than or equal to 5.5:
# Another leaf node with a class label of 1.0 is reached.
# The gini impurity remains low (0.386).
# The total number of samples here is 57,334.
# If “Category y” is greater than 5.5:
# Yet another leaf node with a class label of 0 (negative outcome) is encountered.
# The gini impurity here is 0.479.
# The total number of samples is 37,955.
# Further Levels:
# The tree continues to branch based on additional conditions, but the provided snippet doesn’t reveal the subsequent levels.
# Each leaf node represents a final decision or outcome.
# In summary, this decision tree aims to classify samples based on the “Category y” feature. It splits the data into different classes by recursively evaluating conditions. The gini impurity measures the impurity of the class distribution at each node.
#
# Confusion Matrix:
#
# The confusion matrix shows the counts of true positive, false positive, true negative, and false negative predictions.
# In this case, the confusion matrix is a 2x2 matrix:
# markdown
# Copy code
#     | Predicted 0 | Predicted 1 |
# | Actual 0 |   16494     |     7852     |
# | Actual 1 |       0         |    42362    |
# From this matrix, we can see that the classifier correctly predicted 16494 instances of class 0 (true negatives) and 42362 instances of class 1 (true positives), but misclassified 7852 instances of class 0 as class 1 (false positives).
# Classification Report:
#
# Precision: Precision is the ratio of correctly predicted positive observations to the total predicted positives. For class 0, precision is 1.00, indicating that all items predicted as class 0 were actually class 0. For class 1, precision is 0.84, meaning that 84% of the items predicted as class 1 were actually class 1.
# Recall: Recall is the ratio of correctly predicted positive observations to the all observations in actual class. For class 0, recall is 0.68, indicating that the model correctly identified 68% of all actual class 0 instances. For class 1, recall is 1.00, meaning the model correctly identified all class 1 instances.
# F1-Score: The F1-score is the weighted average of Precision and Recall. It's a useful metric when the classes are imbalanced. For class 0, the F1-score is 0.81, and for class 1, it's 0.92.
# Support: The support is the number of actual occurrences of the class in the specified dataset.
# Accuracy:
#
# Accuracy is the proportion of correctly classified instances among all instances. Here, the overall accuracy is 0.88, meaning the model correctly classified 88% of the instances in the testing subset.
# Macro Average and Weighted Average:
#
# Macro Average: It's the unweighted mean of precision, recall, and F1-score across all classes. Here, the macro average precision is 0.92, recall is 0.84, and F1-score is 0.86.
# Weighted Average: It's the weighted mean of precision, recall, and F1-score across all classes, weighted by the number of instances in each class. Here, the weighted average precision is 0.90, recall is 0.88, and F1-score is 0.88.
#
# Decision Tree Confusion Matrix
# True Negatives (TN):
# The top-left cell represents the count of true negatives.
# In this case, there were 16,494 instances correctly identified as class 0 (negative outcome).
# False Positives (FP):
# The top-right cell represents the count of false positives.
# These are instances incorrectly predicted as class 1 (positive outcome) when they were actually class 0.
# The count here is 7,852.
# False Negatives (FN):
# The bottom-left cell indicates false negatives.
# Surprisingly, there were zero instances incorrectly predicted as class 0 when they were actually class 1.
# True Positives (TP):
# The bottom-right cell represents true positives.
# These are instances correctly identified as class 1.
# The count here is 42,362.
# Interpretation:
#
# The model excels in predicting class 1 (positive outcome), as evidenced by the high number of true positives.
# However, it does make some errors in predicting class 0 (negative outcome), as indicated by the false positives.
# The absence of false negatives suggests that the model is robust in identifying class 1 instances.
#
# KNN
# Confusion Matrix:
#
# The confusion matrix shows the counts of true positive, false positive, true negative, and false negative predictions.
# In this case, the confusion matrix is a 2x2 matrix:
# yaml
# Copy code
#     | Predicted 0 | Predicted 1 |
# | Actual 0 |   21908     |     2438     |
# | Actual 1 |     2293       |    40069    |
# From this matrix, we can see that the classifier correctly predicted 21908 instances of class 0 (true negatives) and 40069 instances of class 1 (true positives), but misclassified 2438 instances of class 0 as class 1 (false positives) and 2293 instances of class 1 as class 0 (false negatives).
# Classification Report:
#
# Precision: Precision is the ratio of correctly predicted positive observations to the total predicted positives. For class 0, precision is 0.91, indicating that 91% of the items predicted as class 0 were actually class 0. For class 1, precision is 0.94, meaning that 94% of the items predicted as class 1 were actually class 1.
# Recall: Recall is the ratio of correctly predicted positive observations to all observations in the actual class. For class 0, recall is 0.90, indicating that the model correctly identified 90% of all actual class 0 instances. For class 1, recall is 0.95, meaning the model correctly identified 95% of all actual class 1 instances.
# F1-Score: The F1-score is the weighted average of Precision and Recall. It's a useful metric when the classes are imbalanced. For class 0, the F1-score is 0.90, and for class 1, it's 0.94.
# Support: The support is the number of actual occurrences of the class in the specified dataset.
# Accuracy:
#
# Accuracy is the proportion of correctly classified instances among all instances. Here, the overall accuracy is 0.93, meaning the model correctly classified 93% of the instances in the testing subset.
# Macro Average and Weighted Average:
#
# Macro Average: It's the unweighted mean of precision, recall, and F1-score across all classes. Here, the macro average precision is 0.92, recall is 0.92, and F1-score is 0.92.
# Weighted Average: It's the weighted mean of precision, recall, and F1-score across all classes, weighted by the number of instances in each class. Here, the weighted average precision is 0.93, recall is 0.93, and F1-score is 0.93.
#
# KNN confusion Matrix interpretation
# True Negatives (TN):
# The top-left cell represents the count of true negatives.
# In this case, there were 22,000 instances correctly identified as class 0 (negative outcome).
# False Positives (FP):
# The top-right cell represents the count of false positives.
# These are instances incorrectly predicted as class 1 (positive outcome) when they were actually class 0.
# The count here is 2,400.
# False Negatives (FN):
# The bottom-left cell indicates false negatives.
# Surprisingly, there were zero instances incorrectly predicted as class 0 when they were actually class 1.
# True Positives (TP):
# The bottom-right cell represents true positives.
# These are instances correctly identified as class 1.
# The count here is 40,000.
# Interpretation:
#
# The model excels in predicting class 1 (positive outcome), as evidenced by the high number of true positives.
# However, it does make some errors in predicting class 0 (negative outcome), as indicated by the false positives.
# The absence of false negatives suggests that the model is robust in identifying class 1 instances.
# Remember that the choice of thresholds and the specific problem context play a crucial role in interpreting a confusion matrix. Overall, this Decision Tree model seems to perform well, but further analysis and domain-specific considerations are essential for a comprehensive evaluation.
#
# Logistic Regression
# Confusion Matrix:
#
# The confusion matrix shows the counts of true positive, false positive, true negative, and false negative predictions.
# In this case, the confusion matrix is a 2x2 matrix:
# yaml
# Copy code
#     | Predicted 0 | Predicted 1 |
# | Actual 0 |   4249     |     20097     |
# | Actual 1 |     3343       |    39019    |
# From this matrix, we can see that the classifier correctly predicted 4249 instances of class 0 (true negatives) and 39019 instances of class 1 (true positives), but misclassified 20097 instances of class 0 as class 1 (false positives) and 3343 instances of class 1 as class 0 (false negatives).
# Classification Report:
#
# Precision: Precision is the ratio of correctly predicted positive observations to the total predicted positives. For class 0, precision is 0.56, indicating that 56% of the items predicted as class 0 were actually class 0. For class 1, precision is 0.66, meaning that 66% of the items predicted as class 1 were actually class 1.
# Recall: Recall is the ratio of correctly predicted positive observations to all observations in the actual class. For class 0, recall is 0.17, indicating that the model correctly identified only 17% of all actual class 0 instances. For class 1, recall is 0.92, meaning the model correctly identified 92% of all actual class 1 instances.
# F1-Score: The F1-score is the weighted average of Precision and Recall. It's a useful metric when the classes are imbalanced. For class 0, the F1-score is 0.27, and for class 1, it's 0.77.
# Support: The support is the number of actual occurrences of the class in the specified dataset.
# Accuracy:
#
# Accuracy is the proportion of correctly classified instances among all instances. Here, the overall accuracy is 0.65, meaning the model correctly classified 65% of the instances in the testing subset.
# Macro Average and Weighted Average:
#
# Macro Average: It's the unweighted mean of precision, recall, and F1-score across all classes. Here, the macro average precision is 0.61, recall is 0.55, and F1-score is 0.52.
# Weighted Average: It's the weighted mean of precision, recall, and F1-score across all classes, weighted by the number of instances in each class. Here, the weighted average precision is 0.62, recall is 0.65, and F1-score is 0.59.
# Confusion Matrix
# True Negatives (TN):
# The top-left cell represents the count of true negatives.
# There were 4,200 instances correctly identified as class 0 (negative outcome).
# False Positives (FP):
# The top-right cell represents the count of false positives.
# These are instances incorrectly predicted as class 1 (positive outcome) when they were actually class 0.
# The count here is 20,000.
# False Negatives (FN):
# The bottom-left cell indicates false negatives.
# Surprisingly, there were zero instances incorrectly predicted as class 0 when they were actually class 1.
# True Positives (TP):
# The bottom-right cell represents true positives.
# These are instances correctly identified as class 1.
# The count here is 39,000.
# Interpretation:
#
# The model excels in predicting class 1 (positive outcome), as evidenced by the high number of true positives.
# However, it does make some errors in predicting class 0 (negative outcome), as indicated by the false positives.
# The absence of false negatives suggests that the model is robust in identifying class 1 instances.
#
# Base Model (Decision Tree):
#
# Decision Tree algorithm is employed for classification.
# The primary splitting criterion is based on the "Category y" feature.
# The tree grows recursively, branching further based on additional conditions.
# The Gini impurity measure is used to evaluate node purity.
# Comparison Models (Logistic Regression | K Nearest Neighbour):
#
# Logistic Regression and K Nearest Neighbors (KNN) algorithms are employed for classification.
# Specific parameter configurations for each model are not provided in the given analysis.
# Managerial Insights
#  Appropriate Model: Compare and Contrast {Decision Tree | Logistic Regression | K Nearest Neighbour}
# Decision Tree:
#
# Utilizes a tree-based approach, making it easy to interpret and explain.
# Efficiently handles both numerical and categorical data.
# May prone to overfitting if not properly pruned.
# Logistic Regression:
#
# Suitable for binary classification tasks.
# Provides probabilities for outcomes, aiding in decision-making.
# Assumes linear relationship between features and log-odds of the outcome.
# K Nearest Neighbour (KNN):
#
# Non-parametric method that relies on instance-based learning.
# Simple to implement and understand.
# Performance may degrade with high-dimensional data and large datasets due to computational complexity.
#  The Decision Tree model seems to perform well in classifying the data based on the "Category y" feature. Logistic Regression and KNN are also viable alternatives.
#  Decision Tree:
#
# Important variables or features are those that result in significant information gain or decrease in impurity when used for splitting nodes.
# Feature importance can be determined based on the feature's position in the tree and the magnitude of impurity reduction.
# The "Category y" feature seems to be crucial in the provided Decision Tree analysis.
# Logistic Regression:
#
# Relevant variables are those that have a significant coefficient in the logistic regression equation.
# Feature selection methods like forward/backward selection or regularization techniques can be used to identify important features.
# Features with large coefficients contribute more to the probability of the outcome.
# K Nearest Neighbour (KNN):
#
# Important variables are those that influence the distance calculation between instances.
# Feature scaling is crucial as KNN is sensitive to the scale of features.
# Features with high variance might dominate the distance calculation, so feature selection or dimensionality reduction techniques can be helpful.

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil
from google.colab import files
import io
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
# Cross Validation
from sklearn.model_selection import cross_val_score

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil
from google.colab import files
import io
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
# Cross Validation
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('df_MFC.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  cluster_number  Product_id  BrandName  Category  \
# 0           0               0     2296012        648         0
# 1           1               1    13780156        428         0
# 2           2               2    11895958        648         6
# 3           3               0     4335679        892         3
# 4           4               2    11690882        648         7
#
#    Individual_category  category_by_Gender  Description  \
# 0                   24                   0        41046
# 1                   75                   0        28448
# 2                   56                   0        41089
# 3                   53                   1        58327
# 4                   79                   1        43301
#
#    OriginalPrice (in Rs)  SizeOption  Ratings  Reviews  DiscountPrice (in Rs)  \
# 0                   1499         131      3.9      999                    317
# 1                   1149         969      4.0      999                    443
# ...

# %%
df.info() # Dataframe Information (Provide Information on Missing Data)
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66708 entries, 0 to 66707
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             66708 non-null  int64
#  1   cluster_number         66708 non-null  int64
#  2   Product_id             66708 non-null  int64
#  3   BrandName              66708 non-null  int64
#  4   Category               66708 non-null  int64
#  5   Individual_category    66708 non-null  int64
#  6   category_by_Gender     66708 non-null  int64
#  7   Description            66708 non-null  int64
#  8   OriginalPrice (in Rs)  66708 non-null  int64
#  9   SizeOption             66708 non-null  int64
#  10  Ratings                66708 non-null  float64
#  11  Reviews                66708 non-null  int64
#  12  DiscountPrice (in Rs)  66708 non-null  int64
#  13  DiscountOffer          66708 non-null  int64
# ...

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Unnamed: 0               0
# cluster_number           0
# Product_id               0
# BrandName                0
# Category                 0
# Individual_category      0
# category_by_Gender       0
# Description              0
# OriginalPrice (in Rs)    0
# SizeOption               0
# Ratings                  0
# Reviews                  0
# DiscountPrice (in Rs)    0
# DiscountOffer            0
# cluster                  0
# dtype: int64

# %%
df_cat=df[['BrandName', 'Category', 'Individual_category', 'category_by_Gender',
       'Description', 'SizeOption']]
df_cat
# Out:
#        BrandName  Category  Individual_category  category_by_Gender  \
# 0            648         0                   24                   0
# 1            428         0                   75                   0
# 2            648         6                   56                   0
# 3            892         3                   53                   1
# 4            648         7                   79                   1
# ...          ...       ...                  ...                 ...
# 66703        511         1                   28                   0
# 66704        328         1                   28                   0
# 66705        893         1                   28                   0
# 66706        820         1                   28                   0
# 66707        182         1                   37                   0
#
#        Description  SizeOption
# 0            41046         131
# 1            28448         969
# 2            41089         810
# ...

# %%
df_non_cat=df[['Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'Reviews',
       'DiscountPrice (in Rs)', 'DiscountOffer']]
df_non_cat
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer
# 0                        317             32
# 1                        443             50
# 2                        459             37
# 3                        393             47
# ...

# %%
df.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66708 entries, 0 to 66707
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             66708 non-null  int64
#  1   cluster_number         66708 non-null  int64
#  2   Product_id             66708 non-null  int64
#  3   BrandName              66708 non-null  int64
#  4   Category               66708 non-null  int64
#  5   Individual_category    66708 non-null  int64
#  6   category_by_Gender     66708 non-null  int64
#  7   Description            66708 non-null  int64
#  8   OriginalPrice (in Rs)  66708 non-null  int64
#  9   SizeOption             66708 non-null  int64
#  10  Ratings                66708 non-null  float64
#  11  Reviews                66708 non-null  int64
#  12  DiscountPrice (in Rs)  66708 non-null  int64
#  13  DiscountOffer          66708 non-null  int64
# ...

# %%
variable_missing_data = df_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# BrandName              0
# Category               0
# Individual_category    0
# category_by_Gender     0
# Description            0
# SizeOption             0
# dtype: int64

# %%
variable_missing_data = df_non_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Product_id               0
# OriginalPrice (in Rs)    0
# Ratings                  0
# Reviews                  0
# DiscountPrice (in Rs)    0
# DiscountOffer            0
# dtype: int64

# %%
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
# Create DataFrame with index and column names
df_cat_code_oe = pd.DataFrame(oe_fit, index=df_cat_mdt_code.index, columns=df_cat_mdt_code.columns)
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_non_cat is your DataFrame containing the required columns
# If not, replace this with your DataFrame name
# Load your data into df_non_cat

# Select the columns for boxplot
columns = ['OriginalPrice (in Rs)', 'Ratings', 'Reviews', 'DiscountPrice (in Rs)', 'DiscountOffer']

# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_non_cat[columns])
plt.title('Boxplot of Features')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
# Create DataFrame with index and column names
df_cat_code_oe = pd.DataFrame(oe_fit, index=df_cat_mdt_code.index, columns=df_cat_mdt_code.columns)
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
df_non_cat_mdt= df_non_cat[['OriginalPrice (in Rs)', 'Ratings', 'Reviews', 'DiscountPrice (in Rs)', 'DiscountOffer']].copy()

# %%
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_non_cat_mdt)
df_non_cat_minmax_norm = pd.DataFrame(mms_fit,index=df_cat_mdt_code.index,columns=df_non_cat_mdt.columns+'_mn'); df_non_cat_minmax_norm
df_non_cat_mdt_mmn = pd.merge(df_non_cat, df_non_cat_minmax_norm, left_index=True, right_index=True); df_non_cat_mdt_mmn
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer  OriginalPrice (in Rs)_mn  \
# 0                        317             32                  0.068945
# 1                        443             50                  0.051331
# ...

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
#Pre-Processed Non-Categorical Data Subset
df_non_cat_ppd = df_non_cat_mdt_mmn.copy(); df_non_cat_ppd # Preferred Data Subset
# Out:
#        Product_id  OriginalPrice (in Rs)  Ratings  Reviews  \
# 0         2296012                   1499      3.9      999
# 1        13780156                   1149      4.0      999
# 2        11895958                   1399      4.3      999
# 3         4335679                   1295      4.2      999
# 4        11690882                    599      4.2      999
# ...           ...                    ...      ...      ...
# 66703    13017776                   2999      4.6       33
# 66704    14604098                   3299      4.3       33
# 66705     7127587                   3398      3.8       33
# 66706    14051584                   3499      4.3       33
# 66707    10263333                   3590      3.8       33
#
#        DiscountPrice (in Rs)  DiscountOffer  OriginalPrice (in Rs)_mn  \
# 0                        317             32                  0.068945
# 1                        443             50                  0.051331
# ...

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_non_cat_ppd); df_ppd # Pre-Processed Dataset
# Out:
#        BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0              648           0                     24                     0
# 1              428           0                     75                     0
# 2              648           6                     56                     0
# 3              892           3                     53                     1
# 4              648           7                     79                     1
# ...            ...         ...                    ...                   ...
# 66703          511           1                     28                     0
# 66704          328           1                     28                     0
# 66705          893           1                     28                     0
# 66706          820           1                     28                     0
# 66707          182           1                     37                     0
#
# ...

# %%
df_ppd = pd.merge(df_cat_ppd, df_non_cat_ppd, left_index=True, right_index=True)

# %%
df_ppd.head(5)
# Out:
#    BrandName_x  Category_x  Individual_category_x  category_by_Gender_x  \
# 0          648           0                     24                     0
# 1          428           0                     75                     0
# 2          648           6                     56                     0
# 3          892           3                     53                     1
# 4          648           7                     79                     1
#
#    Description_x  SizeOption_x  BrandName_y  Category_y  \
# 0          41046           131        648.0         0.0
# 1          28448           969        428.0         0.0
# 2          41089           810        648.0         6.0
# 3          58327           975        892.0         3.0
# 4          43301          1066        648.0         7.0
#
#    Individual_category_y  category_by_Gender_y  ...  OriginalPrice (in Rs)  \
# 0                   24.0                   0.0  ...                   1499
# ...

# %%
# prompt: drop the column which have mn in the end

df_ppd.drop(columns=[col for col in df_ppd.columns if col.endswith('mn')], inplace=True)

# %%
df_ppd.drop(columns=[col for col in df_ppd.columns if col.endswith('x')], inplace=True)

# %%
df_ppd.head(5)
# Out:
#    BrandName_y  Category_y  Individual_category_y  category_by_Gender_y  \
# 0        648.0         0.0                   24.0                   0.0
# 1        428.0         0.0                   75.0                   0.0
# 2        648.0         6.0                   56.0                   0.0
# 3        892.0         3.0                   53.0                   1.0
# 4        648.0         7.0                   79.0                   1.0
#
#    Description_y  SizeOption_y  Product_id  OriginalPrice (in Rs)  Ratings  \
# 0        41046.0         131.0     2296012                   1499      3.9
# 1        28448.0         969.0    13780156                   1149      4.0
# 2        41089.0         810.0    11895958                   1399      4.3
# 3        58327.0         975.0     4335679                   1295      4.2
# 4        43301.0        1066.0    11690882                    599      4.2
#
#    Reviews  DiscountPrice (in Rs)  DiscountOffer
# ...

# %%
df_input = df_ppd[['BrandName_y', 'Category_y', 'Individual_category_y', 'Description_y', 'SizeOption_y', 'Product_id', 'OriginalPrice (in Rs)', 'Ratings', 'DiscountPrice (in Rs)','Reviews','DiscountOffer']]; df_input
# Out:
#        BrandName_y  Category_y  Individual_category_y  Description_y  \
# 0            648.0         0.0                   24.0        41046.0
# 1            428.0         0.0                   75.0        28448.0
# 2            648.0         6.0                   56.0        41089.0
# 3            892.0         3.0                   53.0        58327.0
# 4            648.0         7.0                   79.0        43301.0
# ...            ...         ...                    ...            ...
# 66703        511.0         1.0                   28.0        34412.0
# 66704        328.0         1.0                   28.0        19312.0
# 66705        893.0         1.0                   28.0        58533.0
# 66706        820.0         1.0                   28.0        54700.0
# 66707        182.0         1.0                   37.0         7845.0
#
#        SizeOption_y  Product_id  OriginalPrice (in Rs)  Ratings  \
# 0             131.0     2296012                   1499      3.9
# ...

# %%
df_output = df_ppd[['category_by_Gender_y']]; df_output
# Out:
#        category_by_Gender_y
# 0                       0.0
# 1                       0.0
# 2                       0.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 66703                   0.0
# 66704                   0.0
# 66705                   0.0
# 66706                   0.0
# 66707                   0.0
#
# [66708 rows x 1 columns]

# %%
df_inputs = df_ppd[['BrandName_y', 'Category_y', 'Individual_category_y', 'Description_y',
                        'SizeOption_y', 'Product_id', 'OriginalPrice (in Rs)', 'Ratings',
                        'DiscountPrice (in Rs)','Reviews','DiscountOffer']];df_inputs
# Out:
#        BrandName_y  Category_y  Individual_category_y  Description_y  \
# 0            648.0         0.0                   24.0        41046.0
# 1            428.0         0.0                   75.0        28448.0
# 2            648.0         6.0                   56.0        41089.0
# 3            892.0         3.0                   53.0        58327.0
# 4            648.0         7.0                   79.0        43301.0
# ...            ...         ...                    ...            ...
# 66703        511.0         1.0                   28.0        34412.0
# 66704        328.0         1.0                   28.0        19312.0
# 66705        893.0         1.0                   28.0        58533.0
# 66706        820.0         1.0                   28.0        54700.0
# 66707        182.0         1.0                   37.0         7845.0
#
#        SizeOption_y  Product_id  OriginalPrice (in Rs)  Ratings  \
# 0             131.0     2296012                   1499      3.9
# ...

# %%
df_outputs = df_ppd[['category_by_Gender_y']];df_outputs
# Out:
#        category_by_Gender_y
# 0                       0.0
# 1                       0.0
# 2                       0.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 66703                   0.0
# 66704                   0.0
# 66705                   0.0
# 66706                   0.0
# 66707                   0.0
#
# [66708 rows x 1 columns]

# %%
df_inputs_names = df_inputs.columns; df_inputs_names
df_outputs_labels = df_outputs['category_by_Gender_y'].unique().astype(str); df_outputs_labels
# Out:
# array(['0.0', '1.0'], dtype='<U32')

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45016)

# Perform the stratified split to get training and testing indices
for i, j in stratified_split.split(df, df_output):
    train_df_inputs, test_df_inputs = df.iloc[i], df.iloc[j]
    train_df_output, test_df_output = df_output.iloc[i], df_output.iloc[j]

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45016,max_depth = 3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(df_inputs, df_outputs); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45016)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(df_inputs_names),); print(dtc_model_rules)
# Out:
# |--- Category_y <= 0.50
# |   |--- class: 0.0
# |--- Category_y >  0.50
# |   |--- Category_y <= 6.50
# |   |   |--- Category_y <= 5.50
# |   |   |   |--- class: 1.0
# |   |   |--- Category_y >  5.50
# |   |   |   |--- class: 0.0
# |   |--- Category_y >  6.50
# |   |   |--- class: 1.0

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': df_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 2)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                   feature  importance
# 1              Category_y         1.0
# 0             BrandName_y         0.0
# 2   Individual_category_y         0.0
# 3           Description_y         0.0
# 4            SizeOption_y         0.0
# 5              Product_id         0.0
# 6   OriginalPrice (in Rs)         0.0
# 7                 Ratings         0.0
# 8   DiscountPrice (in Rs)         0.0
# 9                 Reviews         0.0
# 10          DiscountOffer         0.0

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=df_inputs_names, class_names=df_outputs_labels, rounded=True, filled=True, fontsize=8)
plt.show()

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_model_predict_test = dtc_model.predict(df_inputs); dtc_model_predict_test
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(df_outputs, dtc_model_predict_test));print(dtc_predict_conf_mat)
dtc_predict_perf = classification_report(df_outputs, dtc_model_predict_test);  print(dtc_predict_perf)

import time
import psutil

# Record start time
start_time = time.time()

# Record start memory usage
start_memory = psutil.Process().memory_info().rss / 1024 / 1024  # in MB

# Initialize DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='gini', random_state=1234)

# Train the DecisionTreeClassifier on the training data
dtc_model = dtc.fit(df_inputs, df_outputs)

# Make predictions on the test set
y_pred_dtc = dtc_model.predict(df_inputs)

# Record end time
end_time = time.time()

# Record end memory usage
end_memory = psutil.Process().memory_info().rss / 1024 / 1024  # in MB

# Calculate time taken for training and prediction
execution_time = end_time - start_time

# Calculate memory usage increase
memory_increase = end_memory - start_memory

# Print time and memory statistics
print("Execution Time (seconds):", execution_time)
print("Memory Usage Before (MB):", start_memory)
print("Memory Usage After (MB):", end_memory)
print("Memory Usage Increase (MB):", memory_increase)
# Out:
#        0      1
# 0  16494   7852
# 1      0  42362
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.68      0.81     24346
#          1.0       0.84      1.00      0.92     42362
#
#     accuracy                           0.88     66708
#    macro avg       0.92      0.84      0.86     66708
# weighted avg       0.90      0.88      0.88     66708
#
# Execution Time (seconds): 0.31221818923950195
# Memory Usage Before (MB): 365.13671875
# Memory Usage After (MB): 365.6953125
# Memory Usage Increase (MB): 0.55859375

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Initialize and fit the KNN classifier
n=5
knn_classifier = KNeighborsClassifier(n_neighbors=n)  # Adjust n_neighbors as needed
knn_classifier.fit(df_inputs, df_outputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions on the test dataset
knn_predictions = knn_classifier.predict(df_inputs)

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
knn_predict_conf_mat = pd.DataFrame(confusion_matrix(df_outputs, knn_predictions)); print(knn_predict_conf_mat)
knn_predict_perf = classification_report(df_outputs,knn_predictions); print(knn_predict_perf)
# Out:
#        0      1
# 0  21908   2438
# 1   2293  40069
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.90      0.90     24346
#          1.0       0.94      0.95      0.94     42362
#
#     accuracy                           0.93     66708
#    macro avg       0.92      0.92      0.92     66708
# weighted avg       0.93      0.93      0.93     66708

# %%
# Confusion Matrix : Plot [Testing Subset]
ax = plt.axes()
sns.heatmap(knn_predict_conf_mat, annot=True, cmap='Paired')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')
plt.show()

# %%
k_values = [7, 9, 11, 13, 15]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(df_inputs, df_outputs)  # Use your training data here
    y_pred = knn.predict(df_inputs)  # Use your testing data here
    accuracy = accuracy_score(df_outputs,y_pred)  # Compare predictions with true labels
    print(f'Accuracy at k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy at k=7: 0.9077172153264975
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy at k=9: 0.8898033219403969
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy at k=11: 0.87370330395155
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Creating and training the logistic regression model
logistic_regression = LogisticRegression()
logistic_regression.fit(df_inputs, df_outputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Making predictions on the test set
log_predictions = logistic_regression.predict(df_inputs)

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
log_predict_conf_mat = pd.DataFrame(confusion_matrix(df_outputs, log_predictions)); print(log_predict_conf_mat)
log_predict_perf = classification_report(df_outputs,log_predictions); print(log_predict_perf)
# Out:
#       0      1
# 0  4249  20097
# 1  3343  39019
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.17      0.27     24346
#          1.0       0.66      0.92      0.77     42362
#
#     accuracy                           0.65     66708
#    macro avg       0.61      0.55      0.52     66708
# weighted avg       0.62      0.65      0.59     66708

# %%
# Confusion Matrix : Plot [Testing Subset]
ax = plt.axes()
sns.heatmap(log_predict_conf_mat, annot=True, cmap='Paired')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create the SVM Model
svm = SVC(kernel='linear', random_state=45016) # You can adjust the
#kernel and other parameters as needed

# %%
# Train the Model
svm.fit(df_inputs, df_outputs)

# Memory usage
memory_used = memory_usage()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
